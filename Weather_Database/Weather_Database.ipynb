# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the datetime module from the datetime library.
from datetime import datetime

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 749

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_weather_description,
                          "Country": city_country})
                          #"Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | constitucion
# Processing Record 2 of Set 1 | baiyin
# Processing Record 3 of Set 1 | lavrentiya
# Processing Record 4 of Set 1 | yerbogachen
# Processing Record 5 of Set 1 | guiyang
# Processing Record 6 of Set 1 | evensk
# Processing Record 7 of Set 1 | andros town
# Processing Record 8 of Set 1 | bethel
# Processing Record 9 of Set 1 | joshimath
# Processing Record 10 of Set 1 | manta
# Processing Record 11 of Set 1 | poum
# Processing Record 12 of Set 1 | los llanos de aridane
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | isagarh
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | praia da vitoria
# Processing Record 17 of Set 1 | lorengau
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | ribeira grande
# Processing Record 20 of Set 1 | hermanus
# Processing Record 21 of Set 1 | cockburn town
# Processing Record 22 of Set 1 | mount gambier
# Processing Record 23 of Set 1 | east london
# Processing Record 24 of Set 1 | barrow
# Processing Record 25 of Set 1 | arraial do cabo
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | sao joao da barra
# Processing Record 28 of Set 1 | newport
# Processing Record 29 of Set 1 | bubaque
# Processing Record 30 of Set 1 | ponta do sol
# Processing Record 31 of Set 1 | yellowknife
# Processing Record 32 of Set 1 | jamestown
# Processing Record 33 of Set 1 | sibolga
# Processing Record 34 of Set 1 | vaini
# Processing Record 35 of Set 1 | new norfolk
# Processing Record 36 of Set 1 | pacific grove
# Processing Record 37 of Set 1 | manzil tamim
# City not found. Skipping...
# Processing Record 38 of Set 1 | carnarvon
# Processing Record 39 of Set 1 | saint-raymond
# Processing Record 40 of Set 1 | mutsamudu
# City not found. Skipping...
# Processing Record 41 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 1 | sao filipe
# Processing Record 43 of Set 1 | atuona
# Processing Record 44 of Set 1 | hovd
# Processing Record 45 of Set 1 | san matias
# Processing Record 46 of Set 1 | haines junction
# Processing Record 47 of Set 1 | wasilla
# Processing Record 48 of Set 1 | kununurra
# Processing Record 49 of Set 1 | cidreira
# Processing Record 50 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 1 of Set 2 | cape town
# Processing Record 2 of Set 2 | kruisfontein
# Processing Record 3 of Set 2 | urdzhar
# City not found. Skipping...
# Processing Record 4 of Set 2 | linjiang
# Processing Record 5 of Set 2 | broome
# Processing Record 6 of Set 2 | de aar
# Processing Record 7 of Set 2 | georgetown
# Processing Record 8 of Set 2 | saint george
# Processing Record 9 of Set 2 | kasama
# Processing Record 10 of Set 2 | xining
# Processing Record 11 of Set 2 | chokurdakh
# Processing Record 12 of Set 2 | hobart
# Processing Record 13 of Set 2 | yatou
# Processing Record 14 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 2 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 2 | upernavik
# Processing Record 17 of Set 2 | qaanaaq
# Processing Record 18 of Set 2 | lucera
# Processing Record 19 of Set 2 | kodiak
# Processing Record 20 of Set 2 | camacha
# Processing Record 21 of Set 2 | kikwit
# Processing Record 22 of Set 2 | avera
# Processing Record 23 of Set 2 | saskylakh
# Processing Record 24 of Set 2 | butaritari
# Processing Record 25 of Set 2 | puerto ayora
# Processing Record 26 of Set 2 | siniscola
# Processing Record 27 of Set 2 | port alfred
# Processing Record 28 of Set 2 | loksa
# Processing Record 29 of Set 2 | manitouwadge
# Processing Record 30 of Set 2 | sokolow podlaski
# Processing Record 31 of Set 2 | aktash
# Processing Record 32 of Set 2 | gemena
# Processing Record 33 of Set 2 | punta arenas
# Processing Record 34 of Set 2 | coolum beach
# Processing Record 35 of Set 2 | chuy
# Processing Record 36 of Set 2 | shimoda
# Processing Record 37 of Set 2 | kaitangata
# Processing Record 38 of Set 2 | nanortalik
# Processing Record 39 of Set 2 | grand gaube
# Processing Record 40 of Set 2 | egvekinot
# Processing Record 41 of Set 2 | port-cartier
# Processing Record 42 of Set 2 | misratah
# Processing Record 43 of Set 2 | vardo
# Processing Record 44 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 2 | iqaluit
# Processing Record 46 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 2 | bredasdorp
# Processing Record 48 of Set 2 | srednekolymsk
# Processing Record 49 of Set 2 | cherskiy
# Processing Record 50 of Set 2 | tura
# Processing Record 1 of Set 3 | kitimat
# Processing Record 2 of Set 3 | tilichiki
# Processing Record 3 of Set 3 | souillac
# Processing Record 4 of Set 3 | maningrida
# Processing Record 5 of Set 3 | gillette
# Processing Record 6 of Set 3 | torbay
# Processing Record 7 of Set 3 | tuatapere
# Processing Record 8 of Set 3 | milicz
# Processing Record 9 of Set 3 | mar del plata
# Processing Record 10 of Set 3 | busselton
# Processing Record 11 of Set 3 | loandjili
# Processing Record 12 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 3 | mahebourg
# Processing Record 14 of Set 3 | geraldton
# Processing Record 15 of Set 3 | zeya
# Processing Record 16 of Set 3 | khatanga
# Processing Record 17 of Set 3 | klaksvik
# Processing Record 18 of Set 3 | luang prabang
# Processing Record 19 of Set 3 | castro
# Processing Record 20 of Set 3 | kahului
# Processing Record 21 of Set 3 | tazovskiy
# Processing Record 22 of Set 3 | kapaa
# Processing Record 23 of Set 3 | avarua
# Processing Record 24 of Set 3 | hervey bay
# Processing Record 25 of Set 3 | tuktoyaktuk
# Processing Record 26 of Set 3 | tiksi
# Processing Record 27 of Set 3 | scicli
# Processing Record 28 of Set 3 | guangyuan
# Processing Record 29 of Set 3 | goba
# Processing Record 30 of Set 3 | luderitz
# Processing Record 31 of Set 3 | passagem franca
# Processing Record 32 of Set 3 | cayenne
# Processing Record 33 of Set 3 | dabakala
# Processing Record 34 of Set 3 | buala
# Processing Record 35 of Set 3 | coquimbo
# Processing Record 36 of Set 3 | san borja
# Processing Record 37 of Set 3 | eureka
# Processing Record 38 of Set 3 | beausoleil
# Processing Record 39 of Set 3 | codrington
# Processing Record 40 of Set 3 | ancona
# Processing Record 41 of Set 3 | thompson
# Processing Record 42 of Set 3 | champerico
# Processing Record 43 of Set 3 | abnub
# Processing Record 44 of Set 3 | namatanai
# Processing Record 45 of Set 3 | bemidji
# Processing Record 46 of Set 3 | la union
# Processing Record 47 of Set 3 | hithadhoo
# Processing Record 48 of Set 3 | rawson
# Processing Record 49 of Set 3 | saint-philippe
# Processing Record 50 of Set 3 | skjervoy
# Processing Record 1 of Set 4 | asau
# Processing Record 2 of Set 4 | sitka
# Processing Record 3 of Set 4 | guerrero negro
# Processing Record 4 of Set 4 | maun
# Processing Record 5 of Set 4 | victoria
# Processing Record 6 of Set 4 | bindura
# Processing Record 7 of Set 4 | pochinki
# Processing Record 8 of Set 4 | krasnoselkup
# Processing Record 9 of Set 4 | pedernales
# Processing Record 10 of Set 4 | laguna
# Processing Record 11 of Set 4 | nikolskoye
# Processing Record 12 of Set 4 | amot
# Processing Record 13 of Set 4 | maniitsoq
# Processing Record 14 of Set 4 | luzilandia
# Processing Record 15 of Set 4 | santa ana
# Processing Record 16 of Set 4 | provideniya
# Processing Record 17 of Set 4 | maniwaki
# Processing Record 18 of Set 4 | hibbing
# Processing Record 19 of Set 4 | porto uniao
# Processing Record 20 of Set 4 | faanui
# Processing Record 21 of Set 4 | nantucket
# Processing Record 22 of Set 4 | flinders
# Processing Record 23 of Set 4 | rognan
# Processing Record 24 of Set 4 | sinnamary
# Processing Record 25 of Set 4 | candelaria
# Processing Record 26 of Set 4 | puerto quijarro
# Processing Record 27 of Set 4 | dwarka
# Processing Record 28 of Set 4 | ventspils
# Processing Record 29 of Set 4 | emba
# Processing Record 30 of Set 4 | vangaindrano
# Processing Record 31 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 32 of Set 4 | floro
# Processing Record 33 of Set 4 | razole
# Processing Record 34 of Set 4 | libreville
# Processing Record 35 of Set 4 | hilo
# Processing Record 36 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 37 of Set 4 | synya
# Processing Record 38 of Set 4 | bokspits
# City not found. Skipping...
# Processing Record 39 of Set 4 | falam
# Processing Record 40 of Set 4 | antalaha
# Processing Record 41 of Set 4 | bud
# Processing Record 42 of Set 4 | marovoay
# Processing Record 43 of Set 4 | cairns
# Processing Record 44 of Set 4 | general roca
# Processing Record 45 of Set 4 | tasiilaq
# Processing Record 46 of Set 4 | gat
# Processing Record 47 of Set 4 | ridge
# Processing Record 48 of Set 4 | dhidhdhoo
# Processing Record 49 of Set 4 | gladstone
# Processing Record 50 of Set 4 | brae
# Processing Record 1 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 5 | inhambane
# Processing Record 3 of Set 5 | uthal
# Processing Record 4 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 5 | airai
# Processing Record 6 of Set 5 | mandera
# Processing Record 7 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 8 of Set 5 | potosi
# Processing Record 9 of Set 5 | agadez
# Processing Record 10 of Set 5 | rockhampton
# Processing Record 11 of Set 5 | pevek
# Processing Record 12 of Set 5 | antsohihy
# Processing Record 13 of Set 5 | storforshei
# Processing Record 14 of Set 5 | bend
# Processing Record 15 of Set 5 | dalnegorsk
# Processing Record 16 of Set 5 | alenquer
# Processing Record 17 of Set 5 | korla
# Processing Record 18 of Set 5 | san andres
# Processing Record 19 of Set 5 | saint-pierre
# Processing Record 20 of Set 5 | westport
# Processing Record 21 of Set 5 | deputatskiy
# Processing Record 22 of Set 5 | kalmunai
# Processing Record 23 of Set 5 | burica
# City not found. Skipping...
# Processing Record 24 of Set 5 | taltal
# Processing Record 25 of Set 5 | bambous virieux
# Processing Record 26 of Set 5 | saldanha
# Processing Record 27 of Set 5 | katsuura
# Processing Record 28 of Set 5 | port elizabeth
# Processing Record 29 of Set 5 | lagoa
# Processing Record 30 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 31 of Set 5 | sayyan
# Processing Record 32 of Set 5 | wladyslawowo
# Processing Record 33 of Set 5 | dingle
# Processing Record 34 of Set 5 | port maria
# Processing Record 35 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 5 | bon air
# Processing Record 37 of Set 5 | itarema
# Processing Record 38 of Set 5 | la palma
# Processing Record 39 of Set 5 | pemangkat
# Processing Record 40 of Set 5 | najran
# Processing Record 41 of Set 5 | vilhena
# Processing Record 42 of Set 5 | rabo de peixe
# Processing Record 43 of Set 5 | simoes
# Processing Record 44 of Set 5 | vostok
# Processing Record 45 of Set 5 | talnakh
# Processing Record 46 of Set 5 | chillicothe
# Processing Record 47 of Set 5 | mogadishu
# Processing Record 48 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 5 | amuntai
# Processing Record 50 of Set 5 | hofn
# Processing Record 1 of Set 6 | berlevag
# Processing Record 2 of Set 6 | karpogory
# Processing Record 3 of Set 6 | college
# Processing Record 4 of Set 6 | orlik
# Processing Record 5 of Set 6 | anadyr
# Processing Record 6 of Set 6 | murray
# Processing Record 7 of Set 6 | kwidzyn
# Processing Record 8 of Set 6 | bacuit
# City not found. Skipping...
# Processing Record 9 of Set 6 | okhotsk
# Processing Record 10 of Set 6 | zugdidi
# Processing Record 11 of Set 6 | lebu
# Processing Record 12 of Set 6 | marienburg
# Processing Record 13 of Set 6 | chapais
# Processing Record 14 of Set 6 | ust-nera
# Processing Record 15 of Set 6 | aklavik
# Processing Record 16 of Set 6 | terrace
# Processing Record 17 of Set 6 | mount isa
# Processing Record 18 of Set 6 | holme
# Processing Record 19 of Set 6 | floresti
# Processing Record 20 of Set 6 | ambilobe
# Processing Record 21 of Set 6 | prince rupert
# Processing Record 22 of Set 6 | mao
# Processing Record 23 of Set 6 | pangnirtung
# Processing Record 24 of Set 6 | vanimo
# Processing Record 25 of Set 6 | hasaki
# Processing Record 26 of Set 6 | monrovia
# Processing Record 27 of Set 6 | mezen
# Processing Record 28 of Set 6 | longyearbyen
# Processing Record 29 of Set 6 | oktyabrskoye
# Processing Record 30 of Set 6 | ketchikan
# Processing Record 31 of Set 6 | boyolangu
# Processing Record 32 of Set 6 | esperance
# Processing Record 33 of Set 6 | ixtapa
# Processing Record 34 of Set 6 | hambantota
# Processing Record 35 of Set 6 | ojinaga
# Processing Record 36 of Set 6 | tabou
# Processing Record 37 of Set 6 | kavaratti
# Processing Record 38 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 6 | marzuq
# Processing Record 40 of Set 6 | margate
# Processing Record 41 of Set 6 | richards bay
# Processing Record 42 of Set 6 | gravdal
# Processing Record 43 of Set 6 | beringovskiy
# Processing Record 44 of Set 6 | masuda
# Processing Record 45 of Set 6 | la candelaria
# Processing Record 46 of Set 6 | henties bay
# Processing Record 47 of Set 6 | san patricio
# Processing Record 48 of Set 6 | mountrath
# Processing Record 49 of Set 6 | aqtobe
# Processing Record 50 of Set 6 | mundo nuevo
# Processing Record 1 of Set 7 | algiers
# Processing Record 2 of Set 7 | fairbanks
# Processing Record 3 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 4 of Set 7 | te anau
# Processing Record 5 of Set 7 | betare oya
# Processing Record 6 of Set 7 | iquique
# Processing Record 7 of Set 7 | taldom
# Processing Record 8 of Set 7 | anzio
# Processing Record 9 of Set 7 | billings
# Processing Record 10 of Set 7 | tianpeng
# Processing Record 11 of Set 7 | plettenberg bay
# Processing Record 12 of Set 7 | kagoro
# Processing Record 13 of Set 7 | semey
# Processing Record 14 of Set 7 | vila velha
# Processing Record 15 of Set 7 | nhulunbuy
# Processing Record 16 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 7 | padang
# Processing Record 18 of Set 7 | petaluma
# Processing Record 19 of Set 7 | estelle
# Processing Record 20 of Set 7 | joensuu
# Processing Record 21 of Set 7 | druzhba
# Processing Record 22 of Set 7 | carutapera
# Processing Record 23 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 24 of Set 7 | yulara
# Processing Record 25 of Set 7 | kraksaan
# Processing Record 26 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 27 of Set 7 | xichang
# Processing Record 28 of Set 7 | tanggu
# Processing Record 29 of Set 7 | havoysund
# Processing Record 30 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 31 of Set 7 | ostrovnoy
# Processing Record 32 of Set 7 | kalianget
# Processing Record 33 of Set 7 | talcahuano
# Processing Record 34 of Set 7 | zachagansk
# City not found. Skipping...
# Processing Record 35 of Set 7 | anchorage
# Processing Record 36 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 37 of Set 7 | bluff
# Processing Record 38 of Set 7 | ivdel
# Processing Record 39 of Set 7 | atocha
# Processing Record 40 of Set 7 | pisco
# Processing Record 41 of Set 7 | porto novo
# Processing Record 42 of Set 7 | abha
# Processing Record 43 of Set 7 | naryan-mar
# Processing Record 44 of Set 7 | yirol
# City not found. Skipping...
# Processing Record 45 of Set 7 | dolgoye
# Processing Record 46 of Set 7 | cam ranh
# Processing Record 47 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 48 of Set 7 | tabuk
# Processing Record 49 of Set 7 | karratha
# Processing Record 50 of Set 7 | port macquarie
# Processing Record 1 of Set 8 | taicheng
# Processing Record 2 of Set 8 | peace river
# Processing Record 3 of Set 8 | san quintin
# Processing Record 4 of Set 8 | gubkinskiy
# Processing Record 5 of Set 8 | lompoc
# Processing Record 6 of Set 8 | kefamenanu
# Processing Record 7 of Set 8 | taoudenni
# Processing Record 8 of Set 8 | alice springs
# Processing Record 9 of Set 8 | resplendor
# Processing Record 10 of Set 8 | pacifica
# Processing Record 11 of Set 8 | betul
# Processing Record 12 of Set 8 | dongying
# Processing Record 13 of Set 8 | havre-saint-pierre
# Processing Record 14 of Set 8 | kavali
# Processing Record 15 of Set 8 | samarai
# Processing Record 16 of Set 8 | aykhal
# Processing Record 17 of Set 8 | llanes
# Processing Record 18 of Set 8 | leningradskiy
# Processing Record 19 of Set 8 | chimbote
# Processing Record 20 of Set 8 | latehar
# Processing Record 21 of Set 8 | sakakah
# Processing Record 22 of Set 8 | sao gabriel da cachoeira
# Processing Record 23 of Set 8 | tocopilla
# Processing Record 24 of Set 8 | altea
# Processing Record 25 of Set 8 | atka
# City not found. Skipping...
# Processing Record 26 of Set 8 | hadrut
# Processing Record 27 of Set 8 | canaries
# Processing Record 28 of Set 8 | cananeia
# Processing Record 29 of Set 8 | birjand
# Processing Record 30 of Set 8 | port hardy
# Processing Record 31 of Set 8 | santarem
# Processing Record 32 of Set 8 | coahuayana
# Processing Record 33 of Set 8 | albanel
# Processing Record 34 of Set 8 | acari
# Processing Record 35 of Set 8 | catuday
# Processing Record 36 of Set 8 | mehamn
# Processing Record 37 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 8 | lodja
# Processing Record 39 of Set 8 | aflu
# City not found. Skipping...
# Processing Record 40 of Set 8 | yarmouth
# Processing Record 41 of Set 8 | sabha
# Processing Record 42 of Set 8 | fortuna
# Processing Record 43 of Set 8 | gamboula
# Processing Record 44 of Set 8 | panama city
# Processing Record 45 of Set 8 | arroio grande
# Processing Record 46 of Set 8 | ocampo
# Processing Record 47 of Set 8 | ahipara
# Processing Record 48 of Set 8 | black river
# Processing Record 49 of Set 8 | outjo
# Processing Record 50 of Set 8 | bela
# Processing Record 1 of Set 9 | juneau
# Processing Record 2 of Set 9 | soe
# Processing Record 3 of Set 9 | vila franca do campo
# Processing Record 4 of Set 9 | tongliao
# Processing Record 5 of Set 9 | dikson
# Processing Record 6 of Set 9 | lazaro cardenas
# Processing Record 7 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 8 of Set 9 | rio gallegos
# Processing Record 9 of Set 9 | acarau
# Processing Record 10 of Set 9 | ambagarh chauki
# Processing Record 11 of Set 9 | mackay
# Processing Record 12 of Set 9 | safaqis
# City not found. Skipping...
# Processing Record 13 of Set 9 | cristalina
# Processing Record 14 of Set 9 | halifax
# Processing Record 15 of Set 9 | hazorasp
# Processing Record 16 of Set 9 | auburn
# Processing Record 17 of Set 9 | osijek
# Processing Record 18 of Set 9 | santa cruz de tenerife
# Processing Record 19 of Set 9 | severo-kurilsk
# Processing Record 20 of Set 9 | mazamari
# Processing Record 21 of Set 9 | rocha
# Processing Record 22 of Set 9 | smithers
# Processing Record 23 of Set 9 | basco
# Processing Record 24 of Set 9 | muros
# Processing Record 25 of Set 9 | iguatemi
# Processing Record 26 of Set 9 | basse
# Processing Record 27 of Set 9 | gilgit
# Processing Record 28 of Set 9 | sorland
# Processing Record 29 of Set 9 | saryagash
# Processing Record 30 of Set 9 | belmonte
# Processing Record 31 of Set 9 | lira
# Processing Record 32 of Set 9 | belyy yar
# Processing Record 33 of Set 9 | goderich
# Processing Record 34 of Set 9 | lensk
# Processing Record 35 of Set 9 | kibondo
# Processing Record 36 of Set 9 | west wendover
# Processing Record 37 of Set 9 | agirish
# Processing Record 38 of Set 9 | komsomolskiy
# Processing Record 39 of Set 9 | dangriga
# Processing Record 40 of Set 9 | neftekumsk
# Processing Record 41 of Set 9 | mazagao
# Processing Record 42 of Set 9 | upington
# Processing Record 43 of Set 9 | honiara
# Processing Record 44 of Set 9 | nosy varika
# Processing Record 45 of Set 9 | mamlyutka
# Processing Record 46 of Set 9 | bengkulu
# Processing Record 47 of Set 9 | cabra
# Processing Record 48 of Set 9 | redmond
# Processing Record 49 of Set 9 | hellin
# Processing Record 50 of Set 9 | cheremukhovo
# Processing Record 1 of Set 10 | itapirapua
# Processing Record 2 of Set 10 | pozo colorado
# Processing Record 3 of Set 10 | jurado
# Processing Record 4 of Set 10 | urucara
# Processing Record 5 of Set 10 | morros
# Processing Record 6 of Set 10 | parkes
# Processing Record 7 of Set 10 | rayagada
# Processing Record 8 of Set 10 | araouane
# Processing Record 9 of Set 10 | port keats
# Processing Record 10 of Set 10 | seryshevo
# Processing Record 11 of Set 10 | adrar
# Processing Record 12 of Set 10 | broken hill
# Processing Record 13 of Set 10 | sovetskaya gavan
# Processing Record 14 of Set 10 | maseru
# Processing Record 15 of Set 10 | nabire
# Processing Record 16 of Set 10 | strezhevoy
# Processing Record 17 of Set 10 | mitsamiouli
# Processing Record 18 of Set 10 | sisimiut
# Processing Record 19 of Set 10 | portland
# Processing Record 20 of Set 10 | kuala krai
# City not found. Skipping...
# Processing Record 21 of Set 10 | bandarbeyla
# Processing Record 22 of Set 10 | toamasina
# Processing Record 23 of Set 10 | palana
# Processing Record 24 of Set 10 | ust-tsilma
# Processing Record 25 of Set 10 | concarneau
# Processing Record 26 of Set 10 | cabo san lucas
# Processing Record 27 of Set 10 | bilibino
# Processing Record 28 of Set 10 | troitskoye
# Processing Record 29 of Set 10 | olinda
# Processing Record 30 of Set 10 | klyuchi
# Processing Record 31 of Set 10 | tete
# Processing Record 32 of Set 10 | talaya
# Processing Record 33 of Set 10 | antofagasta
# Processing Record 34 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 35 of Set 10 | alghero
# Processing Record 36 of Set 10 | quetzaltepec
# City not found. Skipping...
# Processing Record 37 of Set 10 | kindia
# Processing Record 38 of Set 10 | roma
# Processing Record 39 of Set 10 | miri
# Processing Record 40 of Set 10 | kaifeng
# Processing Record 41 of Set 10 | manadhoo
# Processing Record 42 of Set 10 | presidente epitacio
# Processing Record 43 of Set 10 | zambezi
# Processing Record 44 of Set 10 | marawi
# Processing Record 45 of Set 10 | caravelas
# Processing Record 46 of Set 10 | ilulissat
# Processing Record 47 of Set 10 | shingu
# Processing Record 48 of Set 10 | palora
# Processing Record 49 of Set 10 | mutoko
# Processing Record 50 of Set 10 | touros
# Processing Record 1 of Set 11 | parabel
# Processing Record 2 of Set 11 | chachapoyas
# Processing Record 3 of Set 11 | kudahuvadhoo
# Processing Record 4 of Set 11 | steamboat springs
# Processing Record 5 of Set 11 | gurgan
# City not found. Skipping...
# Processing Record 6 of Set 11 | chichimila
# Processing Record 7 of Set 11 | lezhe
# Processing Record 8 of Set 11 | awbari
# Processing Record 9 of Set 11 | qena
# Processing Record 10 of Set 11 | severomuysk
# Processing Record 11 of Set 11 | olafsvik
# Processing Record 12 of Set 11 | pyshma
# Processing Record 13 of Set 11 | manggar
# Processing Record 14 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 15 of Set 11 | daman
# Processing Record 16 of Set 11 | seoul
# Processing Record 17 of Set 11 | lauda-konigshofen
# Processing Record 18 of Set 11 | jujuy
# City not found. Skipping...
# Processing Record 19 of Set 11 | roanoke rapids
# Processing Record 20 of Set 11 | tefe
# Processing Record 21 of Set 11 | mykolayiv
# Processing Record 22 of Set 11 | ust-kuyga
# Processing Record 23 of Set 11 | nouadhibou
# Processing Record 24 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 25 of Set 11 | zhigansk
# Processing Record 26 of Set 11 | conde
# Processing Record 27 of Set 11 | boguchany
# Processing Record 28 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 29 of Set 11 | quatre cocos
# Processing Record 30 of Set 11 | amposta
# Processing Record 31 of Set 11 | half moon bay
# Processing Record 32 of Set 11 | barcelos
# Processing Record 33 of Set 11 | mayumba
# Processing Record 34 of Set 11 | balsas
# Processing Record 35 of Set 11 | sivas
# Processing Record 36 of Set 11 | pangkalanbuun
# Processing Record 37 of Set 11 | shelburne
# Processing Record 38 of Set 11 | lasa
# Processing Record 39 of Set 11 | iskateley
# Processing Record 40 of Set 11 | muravlenko
# Processing Record 41 of Set 11 | freeport
# Processing Record 42 of Set 11 | moree
# Processing Record 43 of Set 11 | chicama
# Processing Record 44 of Set 11 | pokosnoye
# Processing Record 45 of Set 11 | ancud
# Processing Record 46 of Set 11 | maputo
# Processing Record 47 of Set 11 | luanda
# Processing Record 48 of Set 11 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 11 | bhuj
# Processing Record 50 of Set 11 | marsa matruh
# Processing Record 1 of Set 12 | vestmannaeyjar
# Processing Record 2 of Set 12 | tessalit
# Processing Record 3 of Set 12 | turiacu
# Processing Record 4 of Set 12 | kimbe
# Processing Record 5 of Set 12 | buta
# Processing Record 6 of Set 12 | barrancabermeja
# Processing Record 7 of Set 12 | maxixe
# Processing Record 8 of Set 12 | novikovo
# Processing Record 9 of Set 12 | elko
# Processing Record 10 of Set 12 | boysun
# Processing Record 11 of Set 12 | mollendo
# Processing Record 12 of Set 12 | kabinda
# Processing Record 13 of Set 12 | diamantino
# Processing Record 14 of Set 12 | kilindoni
# Processing Record 15 of Set 12 | arona
# Processing Record 16 of Set 12 | suntar
# Processing Record 17 of Set 12 | sedelnikovo
# City not found. Skipping...
# Processing Record 18 of Set 12 | lahij
# Processing Record 19 of Set 12 | challans
# Processing Record 20 of Set 12 | tommot
# Processing Record 21 of Set 12 | kanakapura
# Processing Record 22 of Set 12 | menongue
# Processing Record 23 of Set 12 | andenes
# Processing Record 24 of Set 12 | nanzhou
# Processing Record 25 of Set 12 | tiarei
# Processing Record 26 of Set 12 | sangar
# Processing Record 27 of Set 12 | ulladulla
# Processing Record 28 of Set 12 | sechura
# Processing Record 29 of Set 12 | alofi
# Processing Record 30 of Set 12 | husavik
# Processing Record 31 of Set 12 | santa
# Processing Record 32 of Set 12 | qasigiannguit
# Processing Record 33 of Set 12 | tamasi
# Processing Record 34 of Set 12 | batagay-alyta
# Processing Record 35 of Set 12 | sainte-anne-des-monts
# Processing Record 36 of Set 12 | mauguio
# Processing Record 37 of Set 12 | cockburn harbour
# City not found. Skipping...
# Processing Record 38 of Set 12 | raudeberg
# Processing Record 39 of Set 12 | pizarro
# Processing Record 40 of Set 12 | taywarah
# Processing Record 41 of Set 12 | nurota
# Processing Record 42 of Set 12 | muisne
# Processing Record 43 of Set 12 | bintulu
# Processing Record 44 of Set 12 | ulagan
# Processing Record 45 of Set 12 | caborca
# Processing Record 46 of Set 12 | oranjemund
# Processing Record 47 of Set 12 | port lincoln
# Processing Record 48 of Set 12 | faya
# Processing Record 49 of Set 12 | portao
# Processing Record 50 of Set 12 | shubarshi
# Processing Record 1 of Set 13 | carbonia
# Processing Record 2 of Set 13 | bathsheba
# Processing Record 3 of Set 13 | belomorsk
# Processing Record 4 of Set 13 | belz
# Processing Record 5 of Set 13 | presidencia roque saenz pena
# Processing Record 6 of Set 13 | queimadas
# Processing Record 7 of Set 13 | bougouni
# Processing Record 8 of Set 13 | moose factory
# Processing Record 9 of Set 13 | kidal
# Processing Record 10 of Set 13 | palmer
# Processing Record 11 of Set 13 | de-kastri
# Processing Record 12 of Set 13 | hay river
# Processing Record 13 of Set 13 | san vicente
# Processing Record 14 of Set 13 | namibe
# Processing Record 15 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 16 of Set 13 | san cristobal
# Processing Record 17 of Set 13 | shache
# Processing Record 18 of Set 13 | lovozero
# Processing Record 19 of Set 13 | pilar
# Processing Record 20 of Set 13 | tomatlan
# Processing Record 21 of Set 13 | kieta
# Processing Record 22 of Set 13 | tahta
# Processing Record 23 of Set 13 | waipawa
# Processing Record 24 of Set 13 | vigrestad
# Processing Record 25 of Set 13 | ivanivka
# Processing Record 26 of Set 13 | luohe
# Processing Record 27 of Set 13 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 13 | santiago
# Processing Record 29 of Set 13 | covington
# Processing Record 30 of Set 13 | mattru
# Processing Record 31 of Set 13 | cerritos
# Processing Record 32 of Set 13 | labuhan
# Processing Record 33 of Set 13 | khandyga
# Processing Record 34 of Set 13 | graaff-reinet
# Processing Record 35 of Set 13 | kulhudhuffushi
# Processing Record 36 of Set 13 | axim
# Processing Record 37 of Set 13 | novaya ladoga
# Processing Record 38 of Set 13 | kaeo
# Processing Record 39 of Set 13 | mongo
# Processing Record 40 of Set 13 | maumere
# Processing Record 41 of Set 13 | phan rang
# City not found. Skipping...
# Processing Record 42 of Set 13 | amiens
# Processing Record 43 of Set 13 | katangli
# Processing Record 44 of Set 13 | aurad
# Processing Record 45 of Set 13 | uruzgan
# Processing Record 46 of Set 13 | khovu-aksy
# Processing Record 47 of Set 13 | quang ngai
# Processing Record 48 of Set 13 | pietarsaari
# Processing Record 49 of Set 13 | sistranda
# Processing Record 50 of Set 13 | zbarazh
# Processing Record 1 of Set 14 | solikamsk
# Processing Record 2 of Set 14 | anshun
# Processing Record 3 of Set 14 | banda aceh
# Processing Record 4 of Set 14 | grindavik
# Processing Record 5 of Set 14 | zhangye
# Processing Record 6 of Set 14 | kang
# Processing Record 7 of Set 14 | nemuro
# Processing Record 8 of Set 14 | saint-augustin
# Processing Record 9 of Set 14 | kavieng
# Processing Record 10 of Set 14 | agadir
# Processing Record 11 of Set 14 | ferme-neuve
# Processing Record 12 of Set 14 | angoram
# Processing Record 13 of Set 14 | hashimoto
# Processing Record 14 of Set 14 | kyzyl-suu
# Processing Record 15 of Set 14 | tecoanapa
# Processing Record 16 of Set 14 | paso de los toros
# Processing Record 17 of Set 14 | okha
# Processing Record 18 of Set 14 | belen
# Processing Record 19 of Set 14 | northam
# Processing Record 20 of Set 14 | asosa
# Processing Record 21 of Set 14 | callaway
# Processing Record 22 of Set 14 | severnyy
# Processing Record 23 of Set 14 | bentiu
# Processing Record 24 of Set 14 | poddorye
# Processing Record 25 of Set 14 | roald
# Processing Record 26 of Set 14 | nicoya
# Processing Record 27 of Set 14 | rawah
# Processing Record 28 of Set 14 | shchelyayur
# City not found. Skipping...
# Processing Record 29 of Set 14 | tonantins
# Processing Record 30 of Set 14 | mae ramat
# Processing Record 31 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 32 of Set 14 | alexandria
# Processing Record 33 of Set 14 | dunedin
# Processing Record 34 of Set 14 | liverpool
# Processing Record 35 of Set 14 | rohatyn
# Processing Record 36 of Set 14 | cuxhaven
# Processing Record 37 of Set 14 | kostek
# Processing Record 38 of Set 14 | znamenskoye
# Processing Record 39 of Set 14 | yuancheng
# Processing Record 40 of Set 14 | conakry
# Processing Record 41 of Set 14 | marand
# Processing Record 42 of Set 14 | norman wells
# Processing Record 43 of Set 14 | dombarovskiy
# Processing Record 44 of Set 14 | teguise
# Processing Record 45 of Set 14 | erzin
# Processing Record 46 of Set 14 | celestun
# Processing Record 47 of Set 14 | santa rosa
# Processing Record 48 of Set 14 | fujin
# Processing Record 49 of Set 14 | moanda
# Processing Record 50 of Set 14 | coihaique
# Processing Record 1 of Set 15 | moussoro
# Processing Record 2 of Set 15 | kigoma
# Processing Record 3 of Set 15 | darnah
# Processing Record 4 of Set 15 | kirkland lake
# Processing Record 5 of Set 15 | vega de alatorre
# Processing Record 6 of Set 15 | turukhansk
# Processing Record 7 of Set 15 | ferrandina
# Processing Record 8 of Set 15 | puteyets
# Processing Record 9 of Set 15 | gimli
# Processing Record 10 of Set 15 | kloulklubed
# Processing Record 11 of Set 15 | manitowoc
# Processing Record 12 of Set 15 | clyde river
# Processing Record 13 of Set 15 | sola
# Processing Record 14 of Set 15 | paradwip
# City not found. Skipping...
# Processing Record 15 of Set 15 | huarmey
# Processing Record 16 of Set 15 | maghama
# City not found. Skipping...
# Processing Record 17 of Set 15 | pumiao
# Processing Record 18 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 19 of Set 15 | xuddur
# Processing Record 20 of Set 15 | la ronge
# Processing Record 21 of Set 15 | taguatinga
# Processing Record 22 of Set 15 | mandurah
# Processing Record 23 of Set 15 | kamenka
# Processing Record 24 of Set 15 | nautla
# Processing Record 25 of Set 15 | vicksburg
# Processing Record 26 of Set 15 | santa clara
# Processing Record 27 of Set 15 | magadan
# Processing Record 28 of Set 15 | fevralsk
# City not found. Skipping...
# Processing Record 29 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 15 | batemans bay
# Processing Record 31 of Set 15 | kochi
# Processing Record 32 of Set 15 | buluang
# Processing Record 33 of Set 15 | aswan
# Processing Record 34 of Set 15 | nara
# Processing Record 35 of Set 15 | san juan
# Processing Record 36 of Set 15 | tatawin
# Processing Record 37 of Set 15 | safford
# Processing Record 38 of Set 15 | guantanamo
# Processing Record 39 of Set 15 | sao jose de piranhas
# Processing Record 40 of Set 15 | tarauaca
# Processing Record 41 of Set 15 | arauco
# Processing Record 42 of Set 15 | paramirim
# Processing Record 43 of Set 15 | lemesos
# City not found. Skipping...
# Processing Record 44 of Set 15 | biabou
# Processing Record 45 of Set 15 | goksun
# Processing Record 46 of Set 15 | usinsk
# Processing Record 47 of Set 15 | fairview
# Processing Record 48 of Set 15 | praya
# Processing Record 49 of Set 15 | puro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Constitucion -35.3333  -72.4167     60.96        64           0
# 1        Baiyin  36.5583  104.2081     42.80        93          75
# 2    Lavrentiya  65.5833 -171.0000     32.47        74          29
# 3   Yerbogachen  61.2767  108.0108     27.82        87          95
# 4       Guiyang  26.5833  106.7167     71.60        78          75
# 5        Evensk  61.9500  159.2333     28.96        97         100
# 6   Andros Town  24.7000  -77.7667     82.40        61          75
# 7        Bethel  41.3712  -73.4140     61.00        21           1
# 8     Joshimath  30.5667   79.5667     47.21        80          96
# 9         Manta  -0.9500  -80.7333     80.60        78          75
#
#    Wind Speed Weather Description Country
# 0        9.86           clear sky      CL
# 1        8.95          light rain      CN
# 2        0.96    scattered clouds      RU
# 3        6.49     overcast clouds      RU
# 4        4.47       broken clouds      CN
# 5        5.68                snow      RU
# 6       17.27       broken clouds      BS
# 7       17.27           clear sky      US
# 8        2.80     overcast clouds      IN
# 9        6.91       broken clouds      EC

# %%
# Set new column order
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]

# Set dataframe to accept new column order
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Constitucion      CL -35.3333  -72.4167     60.96        64           0
# 1        Baiyin      CN  36.5583  104.2081     42.80        93          75
# 2    Lavrentiya      RU  65.5833 -171.0000     32.47        74          29
# 3   Yerbogachen      RU  61.2767  108.0108     27.82        87          95
# 4       Guiyang      CN  26.5833  106.7167     71.60        78          75
# 5        Evensk      RU  61.9500  159.2333     28.96        97         100
# 6   Andros Town      BS  24.7000  -77.7667     82.40        61          75
# 7        Bethel      US  41.3712  -73.4140     61.00        21           1
# 8     Joshimath      IN  30.5667   79.5667     47.21        80          96
# 9         Manta      EC  -0.9500  -80.7333     80.60        78          75
#
#    Wind Speed Weather Description
# 0        9.86           clear sky
# 1        8.95          light rain
# 2        0.96    scattered clouds
# 3        6.49     overcast clouds
# 4        4.47       broken clouds
# 5        5.68                snow
# 6       17.27       broken clouds
# 7       17.27           clear sky
# 8        2.80     overcast clouds
# 9        6.91       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
